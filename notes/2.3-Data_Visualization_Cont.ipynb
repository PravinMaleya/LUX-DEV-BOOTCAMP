# %% [markdown]
# # Visualization

# %%
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
#List to be plotted
x = [1, 2, 3, 4, 5, 6, 7, 8, 9]
y = [9, 8, 7, 6, 5, 4, 3, 2, 1]

# %% [markdown]
# ### Line graph Using Matplotlib

# %%
plt.plot(x, y)
